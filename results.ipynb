# %%
import pandas as pd

# %%
res_opp1 = pd.read_pickle('results_opp115_2022-08-11.p')
res_opp2 = pd.read_pickle('results_opp115_2.p')
res_ohs1 = pd.read_pickle('results_ohsumed_2022-08-11.p')
res_ohs2 = pd.read_pickle('results_ohsumed_2022-08-12.p')
res_ohs3 = pd.read_pickle('results_ohsumed_3.p')
res_reu1 = pd.read_pickle('results_reuters_1.p')
res_reu2 = pd.read_pickle('results_reuters_2022-08-11.p')

# %%
print('opp115-1      - ', res_opp1[res_opp1['result']!='-'].shape[0])
print('opp115-2      - ', res_opp2[res_opp2['result']!='-'].shape[0])
print('ohsumed-1     - ', res_ohs1[res_ohs1['result']!='-'].shape[0])
print('ohsumed-2     - ', res_ohs2[res_ohs2['result']!='-'].shape[0]) 
print('ohsumed-3     - ', res_ohs3[res_ohs3['result']!='-'].shape[0])
print('reuters-1     - ', res_reu1[res_reu1['result']!='-'].shape[0])
print('reuters-2     - ', res_reu2[res_reu2['result']!='-'].shape[0])
# Out:
# opp115-1      -  94
# opp115-2      -  88
# ohsumed-1     -  20
# ohsumed-2     -  0
# ohsumed-3     -  1
# reuters-1     -  0
# reuters-2     -  0

# %%
res_ohs[res_ohs['result']!='-'].shape
# Out:
# (1, 8)

# %%
res_opp1[res_opp1['result']!='-']
# Out:
#     run  balance_ratio sim_calculation_type  batch_size  n_iter   sim_type  \
# 0     1            0.2              average           1     100     cosine
# 1     2            0.2              average           1     100     cosine
# 2     3            0.2              average           1     100     cosine
# 3     4            0.2              average           1     100     cosine
# 4     5            0.2              average           1     100     cosine
# 5     6            0.2              average           1     100     cosine
# 6     7            0.2              average           1     100     cosine
# 7     8            0.2              average           1     100     cosine
# 8     9            0.2              average           1     100     cosine
# 9    10            0.2              average           1     100     cosine
# 10    1            0.2              average           1     100  euclidean
# ...

# %%
res_ohs1[res_ohs1['result']!='-']
# Out:
#    run  balance_ratio sim_calculation_type  batch_size  n_iter sim_type  \
# 0    1            0.2              average           1     100   cosine
#
#   single_metric                                             result
# 0      f1_score  [{'shape_before': 383, 'shape_after': 461, 'va...
